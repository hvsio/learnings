# %%
import pandas as pd
import numpy as np
from enum import Enum
from sqlalchemy import create_engine, types
import typing
import re
from IPython.display import display
import unicodedata
import logging

logging.basicConfig()
logging.getLogger('sqlalchemy.engine').setLevel(logging.ERROR)
#do logging
#check good practices in jupyter
#check lambdas
#create a user
#make. remark in readme about kmpl and engine description

engine = create_engine(
    "postgresql://postgres:postgres@127.0.0.1:5432/car-trade")
engine.connect()
data = pd.read_csv('./data.csv')

# %%
class Constraints:
    def semantic_integrity(df: pd.DataFrame):
        '''
            Ensure non negative numerical values. 
        '''
        for column in df.columns:
            if re.match(r'(float|int)[0-9]{0,2}', str(df[column].dtype)):
                is_empty = (df[column] < 0).any()
                if is_empty:
                    df = df[df[column] >= 0]
        return df
    def domain_constraint(df: pd.DataFrame):
        '''
            Allow only values that match their context. 
        '''
        for column in df.columns:
            regex = ''
            match column:
                case 'gearbox':
                    regex = r'(\d-Speed|CVT)'
                case 'fuel':
                    regex = r'(diesel|petrol|petrol_cng)'
                case 'transmission':
                    regex = r'(automatic|manual)'
            
            if regex:                                           
                edge_cases = df[~df[column].str.match(regex)]
                if len(edge_cases):
                    df = df[~df[column].str.match(regex)]
                    print(f"Unseen value in {column} - {df[column]}.\nConsider adjusting the code or rejecting the entry.")
            return df
                    
    def null_constraint(df: pd.DataFrame):
        '''
            Check for NaN or null values.
        '''
        if len(df[df.isna().any(axis=1)]) != 0:
            raise Exception(
                'Null entries in the dataset, pausing pipeline execution. Handle them before starting cleaning pipeline again.')
        return df
    
    def check_constraint(df: pd.DataFrame, col: str):
        '''
            Check year value validity.
        '''
        has_edge_cases = (df[col] > 2023).any()
        if has_edge_cases:
            print(f"Invalid valuse in column {col}.\nConsider adjusting the code or rejecting the entry.")
        return df

# %%
class NormalizationUtils:
    def normalize_text(df: pd.DataFrame):
        for column in df.columns:
            if df[column].dtype == 'object':
                df[column] = df[column].apply(lambda x: unicodedata.normalize('NFD', x).encode('ascii', 'ignore').decode("utf-8"))
        return df

    def dedup(df: pd.DataFrame):
        if len(df[df.duplicated()]) > 0:
            df = df.drop_duplicates(ignore_index=True)
        return df

    def order_to_numerical(df: pd.DataFrame, col):
        def match_digit(expr):
            regex = r'\d'
            try:
                matched = re.match(regex, expr)
                return matched.group(0)
            except AttributeError as e:
                print(f'Invalid entry, failed to extract the digit in {expr}')

        df[col] = df[col].apply(match_digit)
        return df

    
    def change_types(df: pd.DataFrame):
        for column in df.columns:
            match column:
                case 'kmpl' | 'power' | 'torque':
                    df[column] = pd.to_numeric(
                        df[column], errors='coerce', downcast='float')
                case 'mileage' | 'total_owners' | 'price' | 'production_year' | 'seats_nr' | 'tank_capacity' | 'displacement':
                        df[column] = pd.to_numeric(
                            df[column], errors='coerce', downcast='integer')
            if df[column].dtype == 'object':
                df.astype({column: 'string'})
            if not df[column].notna().all():
                print(f'Conversion introduced NaN values in column {column}. Investigate the data or adjust the db structure accordingly.')
        return df

    def change_name_convention(df: pd.DataFrame):
        '''
            Changing the naming convention to lowercased to easily distinguish SQL queries (capital letters) from queried attributes.
        '''
        df = df.rename(columns={
            'Engine_Type': 'engine_description',
            'CC_Displacement': 'displacement',
            'Transmission': 'gearbox',
            'Transmission_Type': 'transmission',
            'Fuel_Type': 'fuel',
            'Fuel_Tank_Capacity(L)': 'tank_capacity',
            'Make_Year': 'production_year',
            'Mileage_Run': 'mileage',
            'No_of_Owners': 'total_owners',
            'Power(BHP)': 'power',
            'Torque(Nm)': 'torque',
            'Mileage(kmpl)': 'kmpl',
            'Body_Type': 'shape',
            'Seating_Capacity': 'seats_nr',
            'Car_Name': 'series',
            'Make': 'producer'
        })
        df.columns = df.columns.str.lower()
        return df
    
    def clean_bigints(df: pd.DataFrame, cols=[]):
        for column in cols:
            df[column] = df[column].apply(lambda x: x.replace(',', ''))
        return df
    
    
df = (data
      .pipe(NormalizationUtils.change_name_convention)
      .pipe(Constraints.semantic_integrity)
      .pipe(Constraints.null_constraint)
      .pipe(Constraints.domain_constraint)
      .pipe(Constraints.check_constraint, col='production_year')
      .pipe(NormalizationUtils.dedup)
      .pipe(NormalizationUtils.order_to_numerical, col='total_owners')
      .pipe(NormalizationUtils.clean_bigints, cols=['price', 'mileage'])
      .pipe(NormalizationUtils.change_types)
      .pipe(NormalizationUtils.normalize_text)
      ).reset_index(drop=True)

display(df)
# Out:
# Conversion introduced NaN values in column kmpl. Investigate the data or adjust the db structure accordingly.
#                                                 series       producer  \
# 0     Volkswagen Ameo [2016-2017] Highline 1.5L AT (D)     Volkswagen
# 1                Hyundai i20 Active [2015-2020] 1.2 SX        Hyundai
# 2                                 Honda WR-V VX i-VTEC          Honda
# 3                             Renault Kwid 1.0 RXT AMT        Renault
# 4    Hyundai Grand i10 [2017-2020] Asta 1.2 Kappa VTVT        Hyundai
# ..                                                 ...            ...
# 909              Hyundai Verna [2017-2020] 1.6 VTVT SX        Hyundai
# 910              Hyundai Verna [2017-2020] 1.6 VTVT SX        Hyundai
# 911   Hyundai Verna [2011-2015] Fluidic 1.6 VTVT SX AT        Hyundai
# 912    Ford Freestyle [2020-2021] Flair Edition Diesel           Ford
# 913   Maruti Suzuki Ignis [2017-2020] Alpha AMT Petrol  Maruti Suzuki
#
#           model  production_year   color      shape  mileage  total_owners  \
# 0          Ameo             2017  silver      sedan    44611             1
# 1    i20 Active             2016     red  crossover    20305             1
# 2          WR-V             2019   white        suv    29540             2
# 3          Kwid             2017  bronze  hatchback    35680             1
# 4     Grand i10             2017  orange  hatchback    25126             1
# ..          ...              ...     ...        ...      ...           ...
# 909       Verna             2018   white      sedan    23869             1
# 910       Verna             2019   white      sedan    14831             1
# 911       Verna             2014  silver      sedan    52846             1
# 912   Freestyle             2020   white  crossover    28335             2
# 913       Ignis             2018  silver  hatchback    41176             1
#
#      seats_nr    fuel  tank_capacity                      engine_description  \
# 0           5  diesel             45                         1.5L TDI Engine
# 1           5  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 2           5  petrol             40                    i-VTEC Petrol engine
# 3           5  petrol             28                                    1.0L
# 4           5  petrol             43                Kappa VTVT Petrol Engine
# ..        ...     ...            ...                                     ...
# 909         5  petrol             43                       Front Wheel Drive
# 910         5  petrol             43                       Front Wheel Drive
# 911         5  petrol             43                       Front Wheel Drive
# 912         5  diesel             42                 1.5 litre Diesel Engine
# 913         5  petrol             32             1.2-Litre VVT Petrol Engine
#
#      displacement  gearbox transmission       power  torque       kmpl  \
# 0            1498  7-Speed    Automatic  109.000000  250.00  21.660000
# 1            1197  5-Speed       Manual   82.000000  115.00  17.190001
# 2            1199  5-Speed       Manual   88.500000  110.00  16.500000
# 3             999  5-Speed       Manual   67.000000   91.00  21.700001
# 4            1197  5-Speed       Manual   81.860001  113.75  18.900000
# ..            ...      ...          ...         ...     ...        ...
# 909          1591  6-Speed    Automatic  121.000000  158.00  17.400000
# 910          1591  6-Speed    Automatic  121.000000  158.00  17.400000
# 911          1591  4-Speed    Automatic  121.000000  158.00  17.010000
# 912          1499  5-Speed    Automatic   98.959999  215.00  18.500000
# 913          1197  5-Speed    Automatic   81.800003  113.00  20.889999
#
#     emission    price
# 0      BS IV   657000
# 1       BS V   682000
# 2      BS IV   793000
# 3      BS IV   414000
# 4       BS V   515000
# ..       ...      ...
# 909     BS V   956000
# 910     BS V  1027000
# 911   BS III   736000
# 912     BS V   749000
# 913     BS V   691000
#
# [914 rows x 20 columns]

# %% [markdown]
# ### Normalize to 2NF

# %%
'''
    Empirical test for redundant and partially dependent attributes. Determined:
        - shape, seats_nr, tank_capacity, fuel, engine_type, displacement, gearbox, transmission, power, torque, kmpl and emission 
            are functionally dependent on series + producer + model
        - color, production_year, mileage, total_owners, price are functionally dependent on series + id
'''
for i, row in df.iterrows():
    name = row['series']
    edge_cases = df[df['series'] == name]
    if len(edge_cases) > 7:
        display(edge_cases)
# Out:
#                                     series producer       model  \
# 1    Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 76   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 84   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 152  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 162  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 458  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 549  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 670  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 827  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 829  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 1               2016     red  crossover    20305             1         5
# 76              2016   brown  crossover    54744             1         5
# 84              2018   brown  crossover    34075             2         5
# 152             2016     red  crossover    88827             1         5
# 162             2017  silver  crossover    60629             1         5
# 458             2016   white  crossover    88321             1         5
# 549             2018   brown  crossover    24310             1         5
# 670             2018  silver  crossover    29086             1         5
# 827             2017   brown  crossover    43613             1         5
# 829             2018   brown  crossover    35015             2         5
#
#        fuel  tank_capacity                      engine_description  \
# 1    petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 76   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 84   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 152  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 162  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 458  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 549  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 670  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 827  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 829  petrol             45  1.2L Kappa 5 Speed Manual Transmission
#
#      displacement  gearbox transmission  power  torque       kmpl emission  \
# 1            1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 76           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 84           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 152          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 162          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 458          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 549          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 670          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 827          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 829          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
#
#       price
# 1    682000
# 76   625000
# 84   694000
# 152  645000
# 162  725000
# 458  638000
# 549  883000
# 670  843000
# 827  752000
# 829  760000
#                    series producer model  production_year   color shape  \
# 2    Honda WR-V VX i-VTEC    Honda  WR-V             2019   white   suv
# 100  Honda WR-V VX i-VTEC    Honda  WR-V             2017  silver   suv
# 150  Honda WR-V VX i-VTEC    Honda  WR-V             2017     red   suv
# 247  Honda WR-V VX i-VTEC    Honda  WR-V             2017     red   suv
# 339  Honda WR-V VX i-VTEC    Honda  WR-V             2019    grey   suv
# 414  Honda WR-V VX i-VTEC    Honda  WR-V             2019   brown   suv
# 510  Honda WR-V VX i-VTEC    Honda  WR-V             2019     red   suv
# 583  Honda WR-V VX i-VTEC    Honda  WR-V             2017    grey   suv
#
#      mileage  total_owners  seats_nr    fuel  tank_capacity  \
# 2      29540             2         5  petrol             40
# 100    28831             1         5  petrol             40
# 150    88695             1         5  petrol             40
# 247    75639             1         5  petrol             40
# 339    16240             1         5  petrol             40
# 414    23697             1         5  petrol             40
# 510    53948             1         5  petrol             40
# 583    37043             1         5  petrol             40
#
#        engine_description  displacement  gearbox transmission  power  torque  \
# 2    i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 100  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 150  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 247  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 339  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 414  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 510  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
# 583  i-VTEC Petrol engine          1199  5-Speed       Manual   88.5   110.0
#
#      kmpl emission   price
# 2    16.5    BS IV  793000
# 100  16.5    BS IV  791000
# 150  16.5    BS IV  748000
# 247  16.5    BS IV  748000
# 339  16.5    BS IV  894000
# 414  16.5    BS IV  858000
# 510  16.5    BS IV  883000
# 583  16.5    BS IV  745000
#                                        series producer      model  \
# 5    Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 28   Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 105  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 302  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 308  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 350  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 370  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 435  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 578  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 641  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 726  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 732  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 810  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 5               2016     red  hatchback    52261             1         5
# 28              2017     red  hatchback    54233             1         5
# 105             2015     red  hatchback    77836             1         5
# 302             2016     red  hatchback    48481             1         5
# 308             2017    blue  hatchback    63937             1         5
# 350             2016  silver  hatchback    14359             1         5
# 370             2016     red  hatchback    50229             1         5
# 435             2017    grey  hatchback    81673             1         5
# 578             2017    blue  hatchback    85933             1         5
# 641             2016     red  hatchback    56348             1         5
# 726             2017    grey  hatchback    57394             1         5
# 732             2016    grey  hatchback    49826             1         5
# 810             2017     red  hatchback    39427             1         5
#
#        fuel  tank_capacity        engine_description  displacement  gearbox  \
# 5    petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 28   petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 105  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 302  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 308  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 350  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 370  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 435  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 578  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 641  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 726  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 732  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 810  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
#
#     transmission      power      torque  kmpl emission   price
# 5         Manual  81.830002  114.699997  18.6    BS IV  604000
# 28        Manual  81.830002  114.699997  18.6    BS IV  586000
# 105       Manual  81.830002  114.699997  18.6    BS IV  544000
# 302       Manual  81.830002  114.699997  18.6    BS IV  654000
# 308       Manual  81.830002  114.699997  18.6    BS IV  628000
# 350       Manual  81.830002  114.699997  18.6    BS IV  674000
# 370       Manual  81.830002  114.699997  18.6    BS IV  605000
# 435       Manual  81.830002  114.699997  18.6    BS IV  628000
# 578       Manual  81.830002  114.699997  18.6    BS IV  610000
# 641       Manual  81.830002  114.699997  18.6    BS IV  658000
# 726       Manual  81.830002  114.699997  18.6    BS IV  677000
# 732       Manual  81.830002  114.699997  18.6    BS IV  661000
# 810       Manual  81.830002  114.699997  18.6    BS IV  700000
#                                     series producer model  production_year  \
# 24   Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2016
# 372  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2016
# 432  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2016
# 443  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2015
# 449  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2014
# 503  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2014
# 515  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2015
# 522  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2015
# 601  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2014
# 623  Hyundai i10 [2010-2016] Sportz Petrol  Hyundai   i10             2014
#
#       color      shape  mileage  total_owners  seats_nr    fuel  \
# 24    white  hatchback    26910             2         5  petrol
# 372  silver  hatchback    29122             1         5  petrol
# 432    grey  hatchback    36707             1         5  petrol
# 443   white  hatchback    24631             1         5  petrol
# 449    grey  hatchback    41667             2         5  petrol
# 503     red  hatchback    40450             1         5  petrol
# 515   white  hatchback    26176             2         5  petrol
# 522  silver  hatchback    38156             2         5  petrol
# 601    grey  hatchback    98109             1         5  petrol
# 623    grey  hatchback    55319             1         5  petrol
#
#      tank_capacity  engine_description  displacement  gearbox transmission  \
# 24              35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 372             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 432             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 443             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 449             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 503             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 515             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 522             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 601             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
# 623             35  DOHC Kappa2 Engine          1197  5-Speed       Manual
#
#          power      torque       kmpl emission   price
# 24   78.900002  111.800003  20.360001   BS III  396000
# 372  78.900002  111.800003  20.360001   BS III  451000
# 432  78.900002  111.800003  20.360001   BS III  453000
# 443  78.900002  111.800003  20.360001   BS III  444000
# 449  78.900002  111.800003  20.360001   BS III  392000
# 503  78.900002  111.800003  20.360001   BS III  423000
# 515  78.900002  111.800003  20.360001   BS III  408000
# 522  78.900002  111.800003  20.360001   BS III  406000
# 601  78.900002  111.800003  20.360001   BS III  411000
# 623  78.900002  111.800003  20.360001   BS III  439000
#                                         series       producer    model  \
# 27   Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 205  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 240  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 439  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 547  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 570  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 630  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 763  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 778  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
# 811  Maruti Suzuki Celerio [2014-2021] VXi AMT  Maruti Suzuki  Celerio
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 27              2019    grey  hatchback    19550             1         5
# 205             2014  silver  hatchback    63746             3         5
# 240             2014  silver  hatchback    33869             1         5
# 439             2015     red  hatchback    68859             1         5
# 547             2014    grey  hatchback    39400             1         5
# 570             2014  silver  hatchback    87635             1         5
# 630             2014    blue  hatchback     7779             1         5
# 763             2015    blue  hatchback    47060             1         5
# 778             2015  silver  hatchback    24655             1         5
# 811             2014   white  hatchback    52004             1         5
#
#        fuel  tank_capacity engine_description  displacement  gearbox  \
# 27   petrol             35               K10B           998  5-Speed
# 205  petrol             35               K10B           998  5-Speed
# 240  petrol             35               K10B           998  5-Speed
# 439  petrol             35               K10B           998  5-Speed
# 547  petrol             35               K10B           998  5-Speed
# 570  petrol             35               K10B           998  5-Speed
# 630  petrol             35               K10B           998  5-Speed
# 763  petrol             35               K10B           998  5-Speed
# 778  petrol             35               K10B           998  5-Speed
# 811  petrol             35               K10B           998  5-Speed
#
#     transmission      power  torque  kmpl emission   price
# 27        Manual  67.040001    90.0  23.1    BS IV  507000
# 205    Automatic  67.040001    90.0  23.1    BS IV  348000
# 240    Automatic  67.040001    90.0  23.1    BS IV  454000
# 439    Automatic  67.040001    90.0  23.1    BS IV  447000
# 547    Automatic  67.040001    90.0  23.1    BS IV  449000
# 570    Automatic  67.040001    90.0  23.1    BS IV  404000
# 630    Automatic  67.040001    90.0  23.1    BS IV  434000
# 763    Automatic  67.040001    90.0  23.1    BS IV  464000
# 778    Automatic  67.040001    90.0  23.1    BS IV  490000
# 811    Automatic  67.040001    90.0  23.1    BS IV  439000
#                                        series producer      model  \
# 5    Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 28   Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 105  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 302  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 308  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 350  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 370  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 435  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 578  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 641  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 726  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 732  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
# 810  Hyundai Elite i20 [2014-2018] Sportz 1.2  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 5               2016     red  hatchback    52261             1         5
# 28              2017     red  hatchback    54233             1         5
# 105             2015     red  hatchback    77836             1         5
# 302             2016     red  hatchback    48481             1         5
# 308             2017    blue  hatchback    63937             1         5
# 350             2016  silver  hatchback    14359             1         5
# 370             2016     red  hatchback    50229             1         5
# 435             2017    grey  hatchback    81673             1         5
# 578             2017    blue  hatchback    85933             1         5
# 641             2016     red  hatchback    56348             1         5
# 726             2017    grey  hatchback    57394             1         5
# 732             2016    grey  hatchback    49826             1         5
# 810             2017     red  hatchback    39427             1         5
#
#        fuel  tank_capacity        engine_description  displacement  gearbox  \
# 5    petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 28   petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 105  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 302  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 308  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 350  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 370  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 435  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 578  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 641  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 726  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 732  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 810  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
#
#     transmission      power      torque  kmpl emission   price
# 5         Manual  81.830002  114.699997  18.6    BS IV  604000
# 28        Manual  81.830002  114.699997  18.6    BS IV  586000
# 105       Manual  81.830002  114.699997  18.6    BS IV  544000
# 302       Manual  81.830002  114.699997  18.6    BS IV  654000
# 308       Manual  81.830002  114.699997  18.6    BS IV  628000
# 350       Manual  81.830002  114.699997  18.6    BS IV  674000
# 370       Manual  81.830002  114.699997  18.6    BS IV  605000
# 435       Manual  81.830002  114.699997  18.6    BS IV  628000
# 578       Manual  81.830002  114.699997  18.6    BS IV  610000
# 641       Manual  81.830002  114.699997  18.6    BS IV  658000
# 726       Manual  81.830002  114.699997  18.6    BS IV  677000
# 732       Manual  81.830002  114.699997  18.6    BS IV  661000
# 810       Manual  81.830002  114.699997  18.6    BS IV  700000
#                                      series       producer     model  \
# 30   Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 353  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 434  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 478  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 480  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 484  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 594  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 619  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 753  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
# 792  Maruti Suzuki Alto K10 [2010-2014] VXi  Maruti Suzuki  Alto K10
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 30              2011     red  hatchback    79565             1         5
# 353             2011  silver  hatchback    41517             2         5
# 434             2011     red  hatchback    69077             1         5
# 478             2013     red  hatchback    74834             1         5
# 480             2013     red  hatchback    59394             1         5
# 484             2011  silver  hatchback    82262             2         5
# 594             2012     red  hatchback    67041             1         5
# 619             2013     red  hatchback    29217             1         5
# 753             2011     red  hatchback    67463             2         5
# 792             2011   black  hatchback    60256             2         5
#
#        fuel  tank_capacity      engine_description  displacement  gearbox  \
# 30   petrol             35  K Series Petrol Engine           998  5-Speed
# 353  petrol             35  K Series Petrol Engine           998  5-Speed
# 434  petrol             35  K Series Petrol Engine           998  5-Speed
# 478  petrol             35  K Series Petrol Engine           998  5-Speed
# 480  petrol             35  K Series Petrol Engine           998  5-Speed
# 484  petrol             35  K Series Petrol Engine           998  5-Speed
# 594  petrol             35  K Series Petrol Engine           998  5-Speed
# 619  petrol             35  K Series Petrol Engine           998  5-Speed
# 753  petrol             35  K Series Petrol Engine           998  5-Speed
# 792  petrol             35  K Series Petrol Engine           998  5-Speed
#
#     transmission      power  torque   kmpl emission   price
# 30        Manual  67.099998    90.0  20.92    BS IV  237000
# 353       Manual  67.099998    90.0  20.92    BS IV  275000
# 434       Manual  67.099998    90.0  20.92    BS IV  281000
# 478       Manual  67.099998    90.0  20.92    BS IV  301000
# 480       Manual  67.099998    90.0  20.92    BS IV  308000
# 484       Manual  67.099998    90.0  20.92    BS IV  255000
# 594       Manual  67.099998    90.0  20.92    BS IV  314000
# 619       Manual  67.099998    90.0  20.92    BS IV  336000
# 753       Manual  67.099998    90.0  20.92    BS IV  274000
# 792       Manual  67.099998    90.0  20.92    BS IV  245000
#                                          series producer      model  \
# 34   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 78   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 82   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 175  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 332  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 373  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 487  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 747  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 34              2016    grey  hatchback    30797             2         5
# 78              2016   white  hatchback    97573             1         5
# 82              2017   white  hatchback    49775             2         5
# 175             2015  silver  hatchback    37837             1         5
# 332             2016     red  hatchback    95065             1         5
# 373             2016   white  hatchback    71532             2         5
# 487             2015     red  hatchback    29169             1         5
# 747             2016   white  hatchback    25382             1         5
#
#        fuel  tank_capacity                                 engine_description  \
# 34   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 78   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 82   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 175  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 332  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 373  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 487  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 747  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
#
#      displacement  gearbox transmission  power  torque  kmpl emission   price
# 34           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 78           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 82           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  590000
# 175          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  579000
# 332          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  655000
# 373          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  633000
# 487          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  661000
# 747          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  726000
#                                      series producer      model  \
# 43   Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 110  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 206  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 305  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 363  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 436  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 651  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 680  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 713  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
# 815  Hyundai Elite i20 [2014-2018] Asta 1.2  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 43              2014   white  hatchback    96077             1         5
# 110             2015  silver  hatchback    33439             2         5
# 206             2016   white  hatchback    85602             1         5
# 305             2015    grey  hatchback    25517             1         5
# 363             2015    blue  hatchback    80743             1         5
# 436             2017    blue  hatchback    22127             1         5
# 651             2015    grey  hatchback    91933             1         5
# 680             2017    blue  hatchback    57359             1         5
# 713             2014    blue  hatchback    38213             1         5
# 815             2015   white  hatchback    52501             1         5
#
#        fuel  tank_capacity        engine_description  displacement  gearbox  \
# 43   petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 110  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 206  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 305  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 363  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 436  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 651  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 680  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 713  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
# 815  petrol             45  Kappa VTVT Petrol Engine          1197  5-Speed
#
#     transmission      power      torque  kmpl emission   price
# 43        Manual  81.830002  114.699997  18.6    BS IV  530000
# 110       Manual  81.830002  114.699997  18.6    BS IV  575000
# 206       Manual  81.830002  114.699997  18.6    BS IV  659000
# 305       Manual  81.830002  114.699997  18.6    BS IV  669000
# 363       Manual  81.830002  114.699997  18.6    BS IV  622000
# 436       Manual  81.830002  114.699997  18.6    BS IV  713000
# 651       Manual  81.830002  114.699997  18.6    BS IV  603000
# 680       Manual  81.830002  114.699997  18.6    BS IV  744000
# 713       Manual  81.830002  114.699997  18.6    BS IV  635000
# 815       Manual  81.830002  114.699997  18.6    BS IV  662000
#                                             series       producer   model  \
# 57   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 67   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 177  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 201  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 238  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 665  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 729  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 791  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 879  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 57              2015    blue  hatchback    63035             2         5
# 67              2015    blue  hatchback    80408             1         5
# 177             2017    blue  hatchback    15748             1         5
# 201             2017    blue  hatchback    20894             1         5
# 238             2016     red  hatchback    96236             1         5
# 665             2018    blue  hatchback    16373             1         5
# 729             2016    blue  hatchback    56204             2         5
# 791             2018    blue  hatchback    41244             1         5
# 879             2017  orange  hatchback    41465             2         5
#
#        fuel  tank_capacity engine_description  displacement  gearbox  \
# 57   petrol             37    1.2L VVT Engine          1197  5-Speed
# 67   petrol             37    1.2L VVT Engine          1197  5-Speed
# 177  petrol             37    1.2L VVT Engine          1197  5-Speed
# 201  petrol             37    1.2L VVT Engine          1197  5-Speed
# 238  petrol             37    1.2L VVT Engine          1197  5-Speed
# 665  petrol             37    1.2L VVT Engine          1197  5-Speed
# 729  petrol             37    1.2L VVT Engine          1197  5-Speed
# 791  petrol             37    1.2L VVT Engine          1197  5-Speed
# 879  petrol             37    1.2L VVT Engine          1197  5-Speed
#
#     transmission      power  torque   kmpl emission   price
# 57        Manual  81.800003   113.0  21.01     BS V  554000
# 67        Manual  81.800003   113.0  21.01     BS V  568000
# 177       Manual  81.800003   113.0  21.01     BS V  679000
# 201       Manual  81.800003   113.0  21.01     BS V  711000
# 238       Manual  81.800003   113.0  21.01     BS V  639000
# 665       Manual  81.800003   113.0  21.01     BS V  771000
# 729       Manual  81.800003   113.0  21.01     BS V  647000
# 791       Manual  81.800003   113.0  21.01     BS V  764000
# 879       Manual  81.800003   113.0  21.01     BS V  681000
#                                                 series producer      model  \
# 60   Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 129  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 273  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 550  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 652  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 742  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 743  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 831  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 60              2019    grey  hatchback    11734             1         5
# 129             2018    grey  hatchback    16760             1         5
# 273             2017     red  hatchback    11304             1         5
# 550             2017  silver  hatchback    25966             1         5
# 652             2017  silver  hatchback    39437             1         5
# 742             2017   white  hatchback    18411             1         5
# 743             2018    grey  hatchback    42101             1         5
# 831             2018  silver  hatchback    38961             1         5
#
#        fuel  tank_capacity        engine_description  displacement  gearbox  \
# 60   petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 129  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 273  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 550  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 652  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 742  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 743  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 831  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
#
#     transmission      power  torque  kmpl emission   price
# 60        Manual  81.860001  113.75  18.9     BS V  530000
# 129       Manual  81.860001  113.75  18.9     BS V  522000
# 273    Automatic  81.860001  113.75  18.9     BS V  556000
# 550    Automatic  81.860001  113.75  18.9     BS V  544000
# 652    Automatic  81.860001  113.75  18.9     BS V  521000
# 742    Automatic  81.860001  113.75  18.9     BS V  526000
# 743    Automatic  81.860001  113.75  18.9     BS V  571000
# 831    Automatic  81.860001  113.75  18.9     BS V  568000
#                                             series       producer   model  \
# 57   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 67   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 177  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 201  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 238  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 665  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 729  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 791  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 879  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 57              2015    blue  hatchback    63035             2         5
# 67              2015    blue  hatchback    80408             1         5
# 177             2017    blue  hatchback    15748             1         5
# 201             2017    blue  hatchback    20894             1         5
# 238             2016     red  hatchback    96236             1         5
# 665             2018    blue  hatchback    16373             1         5
# 729             2016    blue  hatchback    56204             2         5
# 791             2018    blue  hatchback    41244             1         5
# 879             2017  orange  hatchback    41465             2         5
#
#        fuel  tank_capacity engine_description  displacement  gearbox  \
# 57   petrol             37    1.2L VVT Engine          1197  5-Speed
# 67   petrol             37    1.2L VVT Engine          1197  5-Speed
# 177  petrol             37    1.2L VVT Engine          1197  5-Speed
# 201  petrol             37    1.2L VVT Engine          1197  5-Speed
# 238  petrol             37    1.2L VVT Engine          1197  5-Speed
# 665  petrol             37    1.2L VVT Engine          1197  5-Speed
# 729  petrol             37    1.2L VVT Engine          1197  5-Speed
# 791  petrol             37    1.2L VVT Engine          1197  5-Speed
# 879  petrol             37    1.2L VVT Engine          1197  5-Speed
#
#     transmission      power  torque   kmpl emission   price
# 57        Manual  81.800003   113.0  21.01     BS V  554000
# 67        Manual  81.800003   113.0  21.01     BS V  568000
# 177       Manual  81.800003   113.0  21.01     BS V  679000
# 201       Manual  81.800003   113.0  21.01     BS V  711000
# 238       Manual  81.800003   113.0  21.01     BS V  639000
# 665       Manual  81.800003   113.0  21.01     BS V  771000
# 729       Manual  81.800003   113.0  21.01     BS V  647000
# 791       Manual  81.800003   113.0  21.01     BS V  764000
# 879       Manual  81.800003   113.0  21.01     BS V  681000
#                                     series producer       model  \
# 1    Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 76   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 84   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 152  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 162  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 458  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 549  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 670  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 827  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 829  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 1               2016     red  crossover    20305             1         5
# 76              2016   brown  crossover    54744             1         5
# 84              2018   brown  crossover    34075             2         5
# 152             2016     red  crossover    88827             1         5
# 162             2017  silver  crossover    60629             1         5
# 458             2016   white  crossover    88321             1         5
# 549             2018   brown  crossover    24310             1         5
# 670             2018  silver  crossover    29086             1         5
# 827             2017   brown  crossover    43613             1         5
# 829             2018   brown  crossover    35015             2         5
#
#        fuel  tank_capacity                      engine_description  \
# 1    petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 76   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 84   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 152  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 162  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 458  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 549  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 670  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 827  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 829  petrol             45  1.2L Kappa 5 Speed Manual Transmission
#
#      displacement  gearbox transmission  power  torque       kmpl emission  \
# 1            1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 76           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 84           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 152          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 162          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 458          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 549          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 670          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 827          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 829          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
#
#       price
# 1    682000
# 76   625000
# 84   694000
# 152  645000
# 162  725000
# 458  638000
# 549  883000
# 670  843000
# 827  752000
# 829  760000
#                                          series producer      model  \
# 34   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 78   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 82   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 175  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 332  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 373  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 487  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 747  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 34              2016    grey  hatchback    30797             2         5
# 78              2016   white  hatchback    97573             1         5
# 82              2017   white  hatchback    49775             2         5
# 175             2015  silver  hatchback    37837             1         5
# 332             2016     red  hatchback    95065             1         5
# 373             2016   white  hatchback    71532             2         5
# 487             2015     red  hatchback    29169             1         5
# 747             2016   white  hatchback    25382             1         5
#
#        fuel  tank_capacity                                 engine_description  \
# 34   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 78   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 82   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 175  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 332  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 373  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 487  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 747  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
#
#      displacement  gearbox transmission  power  torque  kmpl emission   price
# 34           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 78           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 82           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  590000
# 175          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  579000
# 332          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  655000
# 373          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  633000
# 487          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  661000
# 747          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  726000
#                                          series producer      model  \
# 34   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 78   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 82   Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 175  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 332  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 373  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 487  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
# 747  Hyundai Elite i20 [2014-2018] Asta 1.2 (O)  Hyundai  Elite i20
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 34              2016    grey  hatchback    30797             2         5
# 78              2016   white  hatchback    97573             1         5
# 82              2017   white  hatchback    49775             2         5
# 175             2015  silver  hatchback    37837             1         5
# 332             2016     red  hatchback    95065             1         5
# 373             2016   white  hatchback    71532             2         5
# 487             2015     red  hatchback    29169             1         5
# 747             2016   white  hatchback    25382             1         5
#
#        fuel  tank_capacity                                 engine_description  \
# 34   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 78   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 82   petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 175  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 332  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 373  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 487  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
# 747  petrol             45  1.2 Kappa petrol with dual VTVT, 16 Valves, 4 ...
#
#      displacement  gearbox transmission  power  torque  kmpl emission   price
# 34           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 78           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  571000
# 82           1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  590000
# 175          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  579000
# 332          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  655000
# 373          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  633000
# 487          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  661000
# 747          1197  5-Speed       Manual   82.0   115.0  18.6    BS IV  726000
#                                     series producer       model  \
# 1    Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 76   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 84   Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 152  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 162  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 458  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 549  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 670  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 827  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 829  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 1               2016     red  crossover    20305             1         5
# 76              2016   brown  crossover    54744             1         5
# 84              2018   brown  crossover    34075             2         5
# 152             2016     red  crossover    88827             1         5
# 162             2017  silver  crossover    60629             1         5
# 458             2016   white  crossover    88321             1         5
# 549             2018   brown  crossover    24310             1         5
# 670             2018  silver  crossover    29086             1         5
# 827             2017   brown  crossover    43613             1         5
# 829             2018   brown  crossover    35015             2         5
#
#        fuel  tank_capacity                      engine_description  \
# 1    petrol             45  1.2L Kappa 5 Speed Manual Transmission
# ...
# 549  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 670  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 827  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
# 829  Hyundai i20 Active [2015-2020] 1.2 SX  Hyundai  i20 Active
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 1               2016     red  crossover    20305             1         5
# 76              2016   brown  crossover    54744             1         5
# 84              2018   brown  crossover    34075             2         5
# 152             2016     red  crossover    88827             1         5
# 162             2017  silver  crossover    60629             1         5
# 458             2016   white  crossover    88321             1         5
# 549             2018   brown  crossover    24310             1         5
# 670             2018  silver  crossover    29086             1         5
# 827             2017   brown  crossover    43613             1         5
# 829             2018   brown  crossover    35015             2         5
#
#        fuel  tank_capacity                      engine_description  \
# 1    petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 76   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 84   petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 152  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 162  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 458  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 549  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 670  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 827  petrol             45  1.2L Kappa 5 Speed Manual Transmission
# 829  petrol             45  1.2L Kappa 5 Speed Manual Transmission
#
#      displacement  gearbox transmission  power  torque       kmpl emission  \
# 1            1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 76           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 84           1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 152          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 162          1197  5-Speed       Manual   82.0   115.0  17.190001     BS V
# 458          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 549          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 670          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 827          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
# 829          1197  5-Speed    Automatic   82.0   115.0  17.190001     BS V
#
#       price
# 1    682000
# 76   625000
# 84   694000
# 152  645000
# 162  725000
# 458  638000
# 549  883000
# 670  843000
# 827  752000
# 829  760000
#                                                 series producer      model  \
# 60   Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 129  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 273  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 550  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 652  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 742  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 743  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
# 831  Hyundai Grand i10 [2017-2020] Magna 1.2 Kappa ...  Hyundai  Grand i10
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 60              2019    grey  hatchback    11734             1         5
# 129             2018    grey  hatchback    16760             1         5
# 273             2017     red  hatchback    11304             1         5
# 550             2017  silver  hatchback    25966             1         5
# 652             2017  silver  hatchback    39437             1         5
# 742             2017   white  hatchback    18411             1         5
# 743             2018    grey  hatchback    42101             1         5
# 831             2018  silver  hatchback    38961             1         5
#
#        fuel  tank_capacity        engine_description  displacement  gearbox  \
# 60   petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 129  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 273  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 550  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 652  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 742  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 743  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
# 831  petrol             43  Kappa VTVT Petrol Engine          1197  5-Speed
#
#     transmission      power  torque  kmpl emission   price
# 60        Manual  81.860001  113.75  18.9     BS V  530000
# 129       Manual  81.860001  113.75  18.9     BS V  522000
# 273    Automatic  81.860001  113.75  18.9     BS V  556000
# 550    Automatic  81.860001  113.75  18.9     BS V  544000
# 652    Automatic  81.860001  113.75  18.9     BS V  521000
# 742    Automatic  81.860001  113.75  18.9     BS V  526000
# 743    Automatic  81.860001  113.75  18.9     BS V  571000
# 831    Automatic  81.860001  113.75  18.9     BS V  568000
#                                      series       producer     model  \
# 420  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 430  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 448  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 513  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 603  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 693  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 737  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 775  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
# 866  Maruti Suzuki Alto K10 [2014-2019] VXi  Maruti Suzuki  Alto K10
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 420             2016    grey  hatchback    21812             1         5
# 430             2017    grey  hatchback    32419             1         5
# 448             2015  silver  hatchback    39807             1         5
# 513             2019    grey  hatchback    35607             1         5
# 603             2018     red  hatchback    64194             1         5
# 693             2015     red  hatchback    74114             2         5
# 737             2015    blue  hatchback    29978             2         5
# 775             2019     red  hatchback    27951             1         5
# 866             2018     red  hatchback    23606             1         5
#
#        fuel  tank_capacity engine_description  displacement  gearbox  \
# 420  petrol             35               K10B           998  5-Speed
# 430  petrol             35               K10B           998  5-Speed
# 448  petrol             35               K10B           998  5-Speed
# 513  petrol             35               K10B           998  5-Speed
# 603  petrol             35               K10B           998  5-Speed
# 693  petrol             35               K10B           998  5-Speed
# 737  petrol             35               K10B           998  5-Speed
# 775  petrol             35               K10B           998  5-Speed
# 866  petrol             35               K10B           998  5-Speed
#
#     transmission  power  torque   kmpl emission   price
# 420       Manual   67.0    90.0  24.07     BS V  362000
# 430       Manual   67.0    90.0  24.07     BS V  396000
# 448       Manual   67.0    90.0  24.07     BS V  352000
# 513       Manual   67.0    90.0  24.07     BS V  429000
# 603       Manual   67.0    90.0  24.07     BS V  405000
# 693       Manual   67.0    90.0  24.07     BS V  320000
# 737       Manual   67.0    90.0  24.07     BS V  350000
# 775       Manual   67.0    90.0  24.07     BS V  425000
# 866       Manual   67.0    90.0  24.07     BS V  395000
#                           series       producer     model  production_year  \
# 132  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2021
# 354  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2021
# 677  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2021
# 704  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2021
# 755  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2019
# 761  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2020
# 820  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2021
# 868  Maruti Suzuki S-Presso VXI+  Maruti Suzuki  S-Presso             2019
#
#       color      shape  mileage  total_owners  seats_nr    fuel  \
# 132     red  hatchback     2163             1         5  petrol
# 354    grey  hatchback    14818             1         5  petrol
# 677  silver  hatchback     4704             1         5  petrol
# 704     red  hatchback    34872             1         5  petrol
# 755   white  hatchback    15878             2         5  petrol
# 761    grey  hatchback     6470             1         5  petrol
# 820    grey  hatchback    15113             1         5  petrol
# 868  orange  hatchback    24105             1         5  petrol
#
#      tank_capacity  engine_description  displacement  gearbox transmission  \
# 132             27  K10B Petrol Engine           998  5-Speed       Manual
# 354             27  K10B Petrol Engine           998  5-Speed       Manual
# 677             27  K10B Petrol Engine           998  5-Speed       Manual
# 704             27  K10B Petrol Engine           998  5-Speed       Manual
# 755             27  K10B Petrol Engine           998  5-Speed       Manual
# 761             27  K10B Petrol Engine           998  5-Speed       Manual
# 820             27  K10B Petrol Engine           998  5-Speed       Manual
# 868             27  K10B Petrol Engine           998  5-Speed       Manual
#
#      power  torque   kmpl emission   price
# 132   67.0    90.0  21.01    BS IV  512000
# 354   67.0    90.0  21.01    BS IV  533000
# 677   67.0    90.0  21.01    BS IV  549000
# 704   67.0    90.0  21.01    BS IV  515000
# 755   67.0    90.0  21.01    BS IV  465000
# 761   67.0    90.0  21.01    BS IV  541000
# 820   67.0    90.0  21.01    BS IV  543000
# 868   67.0    90.0  21.01    BS IV  495000
#                                 series   producer   model  production_year  \
# 140  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2020
# 142  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2020
# 154  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2020
# 562  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2019
# 581  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2019
# 592  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2020
# 606  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2019
# 878  MG Motors Hector 1.5 Sharp DCT AT  MG Motors  Hector             2019
#
#       color shape  mileage  total_owners  seats_nr    fuel  tank_capacity  \
# 140  maroon   suv    33433             1         5  petrol             60
# 142     red   suv    25835             1         5  petrol             60
# 154   black   suv    31271             1         5  petrol             60
# 562     red   suv    25219             1         5  petrol             60
# 581   black   suv    20761             1         5  petrol             60
# 592  silver   suv    26994             1         5  petrol             60
# 606   black   suv    24564             1         5  petrol             60
# 878   white   suv     7339             1         5  petrol             60
#
#     engine_description  displacement  gearbox transmission  power  torque  \
# 140                FWD          1451  6-Speed    Automatic  141.0   250.0
# 142                FWD          1451  6-Speed    Automatic  141.0   250.0
# 154                FWD          1451  6-Speed    Automatic  141.0   250.0
# 562                FWD          1451  6-Speed    Automatic  141.0   250.0
# 581                FWD          1451  6-Speed    Automatic  141.0   250.0
# 592                FWD          1451  6-Speed    Automatic  141.0   250.0
# 606                FWD          1451  6-Speed    Automatic  141.0   250.0
# 878                FWD          1451  6-Speed    Automatic  141.0   250.0
#
#       kmpl emission    price
# 140  13.96    BS IV  1709000
# 142  13.96    BS IV  1770000
# 154  13.96    BS IV  1764000
# 562  13.96    BS IV  1700000
# 581  13.96    BS IV  1720000
# 592  13.96    BS IV  1774000
# 606  13.96    BS IV  1700000
# 878  13.96    BS IV  1799000
#                                             series       producer   model  \
# 57   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 67   Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 177  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 201  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 238  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 665  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 729  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 791  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
# 879  Maruti Suzuki Baleno [2015-2019] Alpha Petrol  Maruti Suzuki  Baleno
#
#      production_year   color      shape  mileage  total_owners  seats_nr  \
# 57              2015    blue  hatchback    63035             2         5
# 67              2015    blue  hatchback    80408             1         5
# 177             2017    blue  hatchback    15748             1         5
# 201             2017    blue  hatchback    20894             1         5
# 238             2016     red  hatchback    96236             1         5
# 665             2018    blue  hatchback    16373             1         5
# 729             2016    blue  hatchback    56204             2         5
# 791             2018    blue  hatchback    41244             1         5
# 879             2017  orange  hatchback    41465             2         5
#
#        fuel  tank_capacity engine_description  displacement  gearbox  \
# 57   petrol             37    1.2L VVT Engine          1197  5-Speed
# 67   petrol             37    1.2L VVT Engine          1197  5-Speed
# 177  petrol             37    1.2L VVT Engine          1197  5-Speed
# 201  petrol             37    1.2L VVT Engine          1197  5-Speed
# 238  petrol             37    1.2L VVT Engine          1197  5-Speed
# 665  petrol             37    1.2L VVT Engine          1197  5-Speed
# 729  petrol             37    1.2L VVT Engine          1197  5-Speed
# 791  petrol             37    1.2L VVT Engine          1197  5-Speed
# 879  petrol             37    1.2L VVT Engine          1197  5-Speed
#
#     transmission      power  torque   kmpl emission   price
# 57        Manual  81.800003   113.0  21.01     BS V  554000
# 67        Manual  81.800003   113.0  21.01     BS V  568000
# 177       Manual  81.800003   113.0  21.01     BS V  679000
# 201       Manual  81.800003   113.0  21.01     BS V  711000
# 238       Manual  81.800003   113.0  21.01     BS V  639000
# 665       Manual  81.800003   113.0  21.01     BS V  771000
# 729       Manual  81.800003   113.0  21.01     BS V  647000
# 791       Manual  81.800003   113.0  21.01     BS V  764000
# 879       Manual  81.800003   113.0  21.01     BS V  681000

# %%
df_car = df[['series', 'color', 'production_year', 'mileage', 'total_owners', 'price']]
df_car_series = df[['producer', 'model', 'shape', 'seats_nr', 'tank_capacity', 'fuel', 'engine_description',
            'displacement', 'gearbox', 'transmission', 'power', 'torque', 'emission', 'kmpl']].drop_duplicates(ignore_index=True)
assert len(df_car.columns) + len(df_car_series.columns) == len(df.columns)

# %%
try: 
    df_car.to_sql(
        'sold_cars',
        engine,
        if_exists='replace',
        index=False,
        dtype={
            'series': types.VARCHAR(70),
            'color': types.VARCHAR(10),
            'production_year': types.SMALLINT, 
            'mileage': types.INT,
            'total_owners': types.SMALLINT, 
            'price': types.INT
        }
    )
except Exception as e:
    print(f'Failed to ingest data into PostgreSQL: {e}')

# %%
try: 
    df_car_series.to_sql(
        'model_details',
        engine,
        if_exists='replace',
        index=False,
        dtype={
            'producer': types.VARCHAR(20), 
            'model': types.VARCHAR(20), 
            'shape': types.VARCHAR(10),
            'seats_nr': types.SMALLINT,
            'tank_capacity': types.INT,
            'fuel': types.VARCHAR(10),
            'engine_type': types.VARCHAR(100),
            'displacement': types.INT,
            'gearbox': types.VARCHAR(20),
            'transmission': types.VARCHAR(20),
            'power': types.FLOAT,
            'torque': types.FLOAT,
            'emission': types.VARCHAR(20),
            'kmpl': types.FLOAT,
        }
    )
except Exception as e:
    print(f'Failed to ingest data into PostgreSQL: {e}')
